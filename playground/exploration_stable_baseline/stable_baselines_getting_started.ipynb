# %%
import gym
from gym import wrappers
from stable_baselines3 import A2C

# %%
env = gym.make('CartPole-v1')

# %%
model = A2C('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=10000)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 542      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | -3.29    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.67     |
# |    value_loss         | 9.75     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 417      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | -299     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.27     |
# |    value_loss         | 5.91     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 373       |
# |    iterations         | 300       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.439    |
# |    explained_variance | -1.94e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -0.432    |
# |    value_loss         | 201       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 400       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -0.654    |
# |    explained_variance | -1.73e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.969     |
# |    value_loss         | 5.48      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 500       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.586    |
# |    explained_variance | -5.46e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.812     |
# |    value_loss         | 4.81      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 600       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.564    |
# |    explained_variance | -8.06e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.849     |
# |    value_loss         | 4.24      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 700       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.534    |
# |    explained_variance | -1.51e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.692     |
# |    value_loss         | 3.71      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 324       |
# |    iterations         | 800       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.435    |
# |    explained_variance | -1.81e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 0.47      |
# |    value_loss         | 3.18      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 310      |
# |    iterations         | 900      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.63    |
# |    explained_variance | -5.9e+05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.786    |
# |    value_loss         | 2.72     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 307       |
# |    iterations         | 1000      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.571    |
# |    explained_variance | -1.19e+06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.856     |
# |    value_loss         | 2.29      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 1100      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.557    |
# |    explained_variance | -1.49e+07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 0.587     |
# |    value_loss         | 1.9       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 1200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.301    |
# |    explained_variance | -2.64e+09 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -25.1     |
# |    value_loss         | 2.83e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 1300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.53     |
# |    explained_variance | -5.85e+07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.583     |
# |    value_loss         | 1.24      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 316       |
# |    iterations         | 1400      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.521    |
# |    explained_variance | -1.43e+08 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.22      |
# |    value_loss         | 0.963     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 318       |
# |    iterations         | 1500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.595    |
# |    explained_variance | -2.17e+07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.369     |
# |    value_loss         | 0.765     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 320       |
# |    iterations         | 1600      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.501    |
# |    explained_variance | -2.91e+09 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.277     |
# |    value_loss         | 0.571     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 1700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | -1.1e+11 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -34      |
# |    value_loss         | 4.92e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 324       |
# |    iterations         | 1800      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.497    |
# |    explained_variance | -1.82e+09 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.315     |
# |    value_loss         | 0.238     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 1900      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.545    |
# |    explained_variance | -4.72e+08 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.195     |
# |    value_loss         | 0.123     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 2000     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.064    |
# |    value_loss         | 0.0441   |
# ------------------------------------

# %%
obs = env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
      obs = env.reset()
